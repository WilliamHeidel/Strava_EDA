# %%
import requests
import json
import time
import os
import pandas as pd
import dlt
from dlt.sources.filesystem import filesystem, read_csv, read_jsonl
from dotenv import load_dotenv

# %%
# === CONFIGURATION ===
load_dotenv()
CLIENT_ID = os.getenv(f'CLIENT_ID')
CLIENT_SECRET = os.getenv(f'CLIENT_SECRET')

TOKENS_FILE = 'secrets/strava_tokens.json'

# %%
# === LOAD OR REFRESH TOKENS ===
def load_tokens():
    if os.path.exists(TOKENS_FILE):
        with open(TOKENS_FILE, 'r') as f:
            return json.load(f)
    else:
        raise FileNotFoundError("Token file not found. Authorize first and save your tokens.")

def save_tokens(tokens):
    with open(TOKENS_FILE, 'w') as f:
        json.dump(tokens, f)

def refresh_tokens(tokens):
    if time.time() > tokens['expires_at']:
        print("Access token expired. Refreshing...")
        response = requests.post("https://www.strava.com/oauth/token", data={
            'client_id': CLIENT_ID,
            'client_secret': CLIENT_SECRET,
            'grant_type': 'refresh_token',
            'refresh_token': tokens['refresh_token']
        })
        new_tokens = response.json()
        tokens.update({
            'access_token': new_tokens['access_token'],
            'refresh_token': new_tokens['refresh_token'],
            'expires_at': new_tokens['expires_at']
        })
        save_tokens(tokens)
    return tokens

# === GET ACTIVITIES ===
def get_activities(access_token, per_page=30):
    headers = {'Authorization': f"Bearer {access_token}"}
    page = 1

    while True:
        response = requests.get(
            'https://www.strava.com/api/v3/athlete/activities',
            headers=headers,
            params={'per_page': per_page, 'page': page}
        )
        data = response.json()

        if not data:
            break

        for activity in data:
            yield activity
        
        page += 1

# %%
# === GET ACTIVITIES ===
def get_activities(access_token, per_page=30):
    headers = {'Authorization': f"Bearer {access_token}"}
    page = 1

    while True:
        response = requests.get(
            'https://www.strava.com/api/v3/athlete/activities',
            headers=headers,
            params={'per_page': per_page, 'page': page}
        )
        data = response.json()

        if not data:
            break

        for activity in data:
            yield activity
        
        page += 1

# %%
def get_athlete(access_token):
    headers = {'Authorization': f"Bearer {access_token}"}

    response = requests.get(
        'https://www.strava.com/api/v3/athlete', #/zones
        headers=headers,
        #params={'per_page': per_page, 'page': page}
    )
    data = response.json()

    return data

athlete_data = get_athlete(ACCESS_TOKEN)
athlete_data
# Out:
# {'message': 'Rate Limit Exceeded',
#  'errors': [{'resource': 'Application',
#    'field': 'read rate limit',
#    'code': 'exceeded'}]}

# %% [raw]
# print(f'https://www.strava.com/oauth/authorize?client_id={CLIENT_ID}&response_type=code&redirect_uri=http://localhost/exchange_token&approval_prompt=force&scope=activity:read_all')

# %% [raw]
# ONE_TIME_CODE = input('Enter Your One Time Code: ')
#
# # One-time token exchange
# response = requests.post("https://www.strava.com/oauth/token", data={
#     'client_id': CLIENT_ID,
#     'client_secret': CLIENT_SECRET,
#     'code': ONE_TIME_CODE,
#     'grant_type': 'authorization_code'
# })
#
# tokens = response.json()
# save_tokens(tokens)

# %%
# === MAIN FLOW ===
tokens = load_tokens()
tokens = refresh_tokens(tokens)
ACCESS_TOKEN=tokens['access_token']

activities_generator = get_activities(ACCESS_TOKEN)

activities = [activity for activity in activities_generator]

# === DISPLAY RESULTS ===
# for act in activities:
#     print(f"{act['start_date'][:10]} - {act['name']} - {act['distance']/1000:.2f} km")

# %%
activities
# Out:
# ['message', 'errors']

# %% [raw]
# import boto3
# from pprint import pprint
#
# # 1) Create a Redshift client in your region
# client = boto3.client("redshift", region_name="us-east-2")
#
# # 2) Enable the Data API on your cluster immediately
# resp = client.modify_cluster(
#     ClusterIdentifier="redshift-cluster-test",   # ← replace with your cluster’s identifier
#     EnableDataApi=True,
#     ApplyImmediately=True
# )
# print("ModifyCluster response:")
# pprint(resp)
#
# # 3) Confirm it’s enabled
# status = client.describe_clusters(
#     ClusterIdentifier="your-cluster-name"
# )["Clusters"][0]["DataApiClusterEnabled"]
# print("Data API enabled?", status)

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth
from dlt.sources.helpers.rest_client.paginators import OffsetPaginator

os.environ["ACCESS_TOKEN"] = ACCESS_TOKEN
@dlt.source
def strava_source(
    access_token=dlt.secrets.value
):
    client = RESTClient(
        base_url='https://www.strava.com/api/v3/',
        auth=BearerTokenAuth(token=access_token),
        paginator=OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    )

    @dlt.resource(
        write_disposition="replace",
        #primary_key="id",
        max_table_nesting=None,
    )
    def activities():
        for page in client.paginate("athlete/activities"):
            yield page

    @dlt.resource(
        write_disposition="replace",
        #primary_key="id",
        max_table_nesting=None,
    )
    def athlete():
        for page in client.paginate("athlete"):
            yield page

    return activities, athlete

# %%
os.environ["NORMALIZE__DATA_WRITER__DISABLE_COMPRESSION"] = "true"
pipeline_s3 = dlt.pipeline(
    pipeline_name="strava_to_s3",       # you can keep the same name if you like
    destination="filesystem",            # ← switch to filesystem
    dataset_name="strava_activities_s3"  # name for the S3 “folder” in your bucket
)
load_info_s3 = pipeline_s3.run(strava_source(), loader_file_format = "jsonl")
#print(load_info_s3)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\extract\pipe_iterator.py:277, in PipeIterator._get_source_item(self)
#     275 set_current_pipe_name(pipe.name)
# --> 277 pipe_item = next(gen)
#     278 if pipe_item is not None:
#     279     # full pipe item may be returned, this is used by ForkPipe step
#     280     # to redirect execution of an item to another pipe
#     281     # else
#
# Cell In[5], line 39, in strava_source.<locals>.athlete()
#      33 @dlt.resource(
#      34     write_disposition="replace",
#      35     #primary_key="id",
#      36     max_table_nesting=None,
#      37 )
#      38 def athlete():
# ---> 39     for page in client.paginate("athlete"):
#      40         yield page
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\sources\helpers\rest_client\client.py:238, in RESTClient.paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, headers, **kwargs)
#     237 try:
# --> 238     response = self._send_request(request, **kwargs)
#     239 except IgnoreResponseException:
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\sources\helpers\rest_client\client.py:144, in RESTClient._send_request(self, request, **kwargs)
#     143 send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 144 return self.session.send(prepared_request, **send_kwargs)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\tenacity\__init__.py:338, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     337 wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 338 return copy(f, *args, **kw)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\tenacity\__init__.py:477, in Retrying.__call__(self, fn, *args, **kwargs)
#     476 while True:
# --> 477     do = self.iter(retry_state=retry_state)
#     478     if isinstance(do, DoAttempt):
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\tenacity\__init__.py:378, in BaseRetrying.iter(self, retry_state)
#     377 for action in self.iter_state.actions:
# --> 378     result = action(retry_state)
#     379 return result
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\sources\helpers\requests\retry.py:131, in _make_retry.<locals>.<lambda>(state)
#     125 wait_cls = wait_exponential_retry_after if respect_retry_after_header else wait_exponential
#     126 return Retrying(
#     127     wait=wait_cls(multiplier=backoff_factor, max=max_delay),
#     128     retry=(retry_any(*retry_conds)),
#     129     stop=stop_after_attempt(max_attempts),
#     130     reraise=True,
# --> 131     retry_error_callback=lambda state: state.outcome.result(),
#     132 )
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     402 try:
# --> 403     raise self._exception
#     404 finally:
#     405     # Break a reference cycle with the exception in self._exception
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\tenacity\__init__.py:480, in Retrying.__call__(self, fn, *args, **kwargs)
#     479 try:
# --> 480     result = fn(*args, **kwargs)
#     481 except BaseException:  # noqa: B902
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\sources\helpers\requests\session.py:61, in Session.send(self, request, **kwargs)
#      60 kwargs.setdefault("timeout", self.timeout)
# ---> 61 return super().send(request, **kwargs)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\requests\sessions.py:710, in Session.send(self, request, **kwargs)
#     709 # Response manipulation hooks
# --> 710 r = dispatch_hook("response", hooks, r, **kwargs)
#     712 # Persist cookies
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\requests\hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\sources\helpers\rest_client\client.py:329, in raise_for_status(response, *args, **kwargs)
#     328 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 329     response.raise_for_status()
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\requests\models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://www.strava.com/api/v3/athlete?page=7201&per_page=100
#
# The above exception was the direct cause of the following exception:
#
# ResourceExtractionError                   Traceback (most recent call last)
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:474, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh, loader_file_format)
#     472         raise SourceExhausted(source.name)
# --> 474     self._extract_source(
#     475         extract_step,
#     476         source,
#     477         max_parallel_items,
#     478         workers,
#     479         refresh=refresh or self.refresh,
#     480     )
#     482 # this will update state version hash so it will not be extracted again by with_state_sync
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:1227, in Pipeline._extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1226 # extract into pipeline schema
# -> 1227 load_id = extract.extract(
#    1228     source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#    1229 )
#    1231 # update live schema but not update the store yet
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\extract\extract.py:440, in Extract.extract(self, source, max_parallel_items, workers, load_package_state_update)
#     438             reset_resource_state(resource.name)
# --> 440 self._extract_single_source(
#     441     load_id,
#     442     source,
#     443     max_parallel_items=max_parallel_items,
#     444     workers=workers,
#     445 )
#     446 commit_load_package_state()
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\extract\extract.py:363, in Extract._extract_single_source(self, load_id, source, max_parallel_items, workers)
#     362 collector.update("Resources", 0, total_gens)
# --> 363 for pipe_item in pipes:
#     364     curr_gens = len(pipes._sources)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\extract\pipe_iterator.py:162, in PipeIterator.__next__(self)
#     160 if pipe_item is None:
#     161     # if none then take element from the newest source
# --> 162     pipe_item = self._get_source_item()
#     164 if pipe_item is None:
#     165     # Wait for some time for futures to resolve
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\extract\pipe_iterator.py:307, in PipeIterator._get_source_item(self)
#     306 except Exception as ex:
# --> 307     raise ResourceExtractionError(pipe.name, gen, str(ex), "generator") from ex
#
# ResourceExtractionError: In processing pipe athlete: extraction of resource athlete in generator athlete caused an exception: 429 Client Error: Too Many Requests for url: https://www.strava.com/api/v3/athlete?page=7201&per_page=100
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# Cell In[6], line 7
#       1 os.environ["NORMALIZE__DATA_WRITER__DISABLE_COMPRESSION"] = "true"
#       2 pipeline_s3 = dlt.pipeline(
#       3     pipeline_name="strava_to_s3",       # you can keep the same name if you like
#       4     destination="filesystem",            # ← switch to filesystem
#       5     dataset_name="strava_activities_s3"  # name for the S3 “folder” in your bucket
#       6 )
# ----> 7 load_info_s3 = pipeline_s3.run(strava_source(), loader_file_format = "jsonl")
#       8 #print(load_info_s3)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:222, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     219     if trace:
#     220         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 222     step_info = f(self, *args, **kwargs)
#     223     return step_info
#     224 except Exception as ex:
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:271, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     263 @wraps(f)
#     264 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     265     # add section context to the container to be used by all configuration without explicit sections resolution
#     266     with inject_section(
#     267         ConfigSectionContext(
#     268             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     269         )
#     270     ):
# --> 271         return f(self, *args, **kwargs)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:718, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     716 # extract from the source
#     717 if data is not None:
# --> 718     self.extract(
#     719         data,
#     720         table_name=table_name,
#     721         write_disposition=write_disposition,
#     722         columns=columns,
#     723         primary_key=primary_key,
#     724         schema=schema,
#     725         table_format=table_format,
#     726         schema_contract=schema_contract,
#     727         refresh=refresh or self.refresh,
#     728         loader_file_format=loader_file_format,
#     729     )
#     730     self.normalize()
#     731     return self.load(destination, dataset_name, credentials=credentials)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:222, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     219     if trace:
#     220         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 222     step_info = f(self, *args, **kwargs)
#     223     return step_info
#     224 except Exception as ex:
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:176, in with_schemas_sync.<locals>._wrap(self, *args, **kwargs)
#     174     self._schema_storage.commit_live_schema(name)
#     175 try:
# --> 176     rv = f(self, *args, **kwargs)
#     177 except Exception:
#     178     # because we committed live schema before calling f, we may safely
#     179     # drop all changes in live schemas
#     180     for name in list(self._schema_storage.live_schemas.keys()):
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:162, in with_state_sync.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     160 should_extract_state = may_extract_state and self.config.restore_from_destination
#     161 with self.managed_state(extract_state=should_extract_state):
# --> 162     return f(self, *args, **kwargs)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:271, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     263 @wraps(f)
#     264 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     265     # add section context to the container to be used by all configuration without explicit sections resolution
#     266     with inject_section(
#     267         ConfigSectionContext(
#     268             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     269         )
#     270     ):
# --> 271         return f(self, *args, **kwargs)
#
# File c:\Users\william.heidel\.conda\envs\generic\lib\site-packages\dlt\pipeline\pipeline.py:495, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh, loader_file_format)
#     493 step_info = self._get_step_info(extract_step)
#     494 current_load_id = step_info.loads_ids[-1] if len(step_info.loads_ids) > 0 else None
# --> 495 raise PipelineStepFailed(
#     496     self,
#     497     "extract",
#     498     current_load_id,
#     499     exc,
#     500     step_info,
#     501 ) from exc
#
# PipelineStepFailed: Pipeline execution failed at stage extract when processing package 1748600330.7960694 with exception:
#
# <class 'dlt.extract.exceptions.ResourceExtractionError'>
# In processing pipe athlete: extraction of resource athlete in generator athlete caused an exception: 429 Client Error: Too Many Requests for url: https://www.strava.com/api/v3/athlete?page=7201&per_page=100

# %%
pipeline = dlt.pipeline(
    pipeline_name="strava_rest_api_redshift",
    destination="redshift",
)
load_info = pipeline.run(strava_source())

# %% [raw]
# pipeline_redshift = dlt.pipeline(
#     pipeline_name="strava_s3_to_redshift",
#     destination="redshift",
#     dataset_name="strava_rest_api_dataset_test",
#     dev_mode=False
# )
#
# source_from_s3 = filesystem(
#     bucket_url="s3://billy-heidel-test-bucket/activities",
#     file_glob="**/*.jsonl"
# )
#
# source_from_s3 = source_from_s3 | read_jsonl()
#
# source_from_s3 = source_from_s3.with_name("activities")
# # Run pipeline to move CSV data from S3 into Redshift
# load_info_redshift = pipeline_redshift.run(source_from_s3, refresh='drop_sources')
# print("Loaded to Redshift:", load_info_redshift)
# print(pipeline_redshift.last_trace.last_normalize_info.row_counts)

# %%
# Define a dlt pipeline with automatic normalization
pipeline = dlt.pipeline(
    destination="duckdb",
    pipeline_name="strava_rest_api",
)

# run the pipeline with the new resource
load_info = pipeline.run(strava_source())

# %%
pipeline.dataset(dataset_type="default").schema.data_table_names()
# Out:
# ['activities', 'activities__start_latlng', 'activities__end_latlng']

# %%
pipeline.dataset(dataset_type="default").activities.df()
# Out:
#     resource_state  athlete__id  athlete__resource_state             name
# 0                2    148269563                        1     Morning Walk  \
# 1                2    148269563                        1      Morning Run
# 2                2    148269563                        1      Morning Run
# 3                2    148269563                        1     Morning Walk
# 4                2    148269563                        1     Morning Walk
# ..             ...          ...                      ...              ...
# 71               2    148269563                        1      Evening Run
# 72               2    148269563                        1      Morning Run
# 73               2    148269563                        1      Morning Run
# 74               2    148269563                        1      Morning Run
# 75               2    148269563                        1  Morning Workout
#
#     distance  moving_time  elapsed_time  total_elevation_gain     type
# 0     1410.3          982           982                  <NA>     Walk  \
# 1     6454.8         1802          1802                     0      Run
# 2     6938.3         1801          1801                     0      Run
# 3     1166.9          897           897                  <NA>     Walk
# 4     1422.2          938           938                  <NA>     Walk
# ..       ...          ...           ...                   ...      ...
# 71     568.6         3321          3321                     0      Run
# 72    7129.3         2613          2613                     0      Run
# 73    5099.3         1533          1533                     0      Run
# 74    6040.3         1589          1589                     0      Run
# 75       0.0           92            92                     0  Workout
#
#    sport_type  ...  upload_id_str                        external_id
# 0        Walk  ...    15611268529           garmin_ping_443437184249  \
# 1         Run  ...    15601242833           garmin_ping_443140876535
# 2         Run  ...    15597334634           garmin_ping_443006351934
# 3        Walk  ...    15588803482           garmin_ping_442780035147
# 4        Walk  ...    15579558715           garmin_ping_442500649377
# ..        ...  ...            ...                                ...
# 71        Run  ...    14524948604           garmin_ping_410575511422
# 72        Run  ...    13310815861  stripped_garmin_ping_372336753957
# 73        Run  ...    13310815879  stripped_garmin_ping_372336753968
# 74        Run  ...    13310818837  stripped_garmin_ping_372336816902
# 75    Workout  ...    13310818836  stripped_garmin_ping_372336816738
#
#    from_accepted_tag pr_count  total_photo_count  has_kudoed
# 0              False        0                  0       False  \
# 1              False        0                  0       False
# 2              False        0                  0       False
# 3              False        0                  0       False
# 4              False        0                  0       False
# ..               ...      ...                ...         ...
# 71             False        0                  0       False
# 72             False        0                  0       False
# 73             False        0                  0       False
# 74             False        0                  0       False
# 75             False        0                  0       False
#
#          _dlt_load_id         _dlt_id  total_elevation_gain__v_double
# 0   1748598390.470637  amFSXtJNuVyt/w                            10.8  \
# 1   1748598390.470637  m6t8iGug/dywtQ                             NaN
# 2   1748598390.470637  GEMoMKHWo2IX2w                             NaN
# 3   1748598390.470637  tp6ky7yFiivshg                             9.7
# 4   1748598390.470637  1OAq369aiSRV6A                            14.5
# ..                ...             ...                             ...
# 71  1748598390.470637  qojgnsRR9R7FLA                             NaN
# 72  1748598390.470637  cpjhAQjaQPcKPw                             NaN
# 73  1748598390.470637  VFBYfJXOlrr9Zg                             NaN
# 74  1748598390.470637  Bas+zTDJ851PKQ                             NaN
# 75  1748598390.470637  /XRZuDPOHwSb2g                             NaN
#
#     workout_type
# 0           <NA>
# 1           <NA>
# 2           <NA>
# 3           <NA>
# 4           <NA>
# ..           ...
# 71          <NA>
# 72          <NA>
# 73          <NA>
# 74          <NA>
# 75          <NA>
#
# [76 rows x 50 columns]

# %%
import duckdb

conn = duckdb.connect(f"strava_rest_api.duckdb")
conn.sql(f"SET search_path = 'strava_rest_api'")
conn.sql("DESCRIBE").df()
# Out:
#           database                   schema                      name
# 0  strava_rest_api  strava_rest_api_dataset                _dlt_loads  \
# 1  strava_rest_api  strava_rest_api_dataset       _dlt_pipeline_state
# 2  strava_rest_api  strava_rest_api_dataset              _dlt_version
# 3  strava_rest_api  strava_rest_api_dataset                activities
# 4  strava_rest_api  strava_rest_api_dataset    activities__end_latlng
# 5  strava_rest_api  strava_rest_api_dataset  activities__start_latlng
#
#                                         column_names
# 0  [load_id, schema_name, status, inserted_at, sc...  \
# 1  [version, engine_version, pipeline_name, state...
# 2  [version, engine_version, inserted_at, schema_...
# 3  [resource_state, athlete__id, athlete__resourc...
# 4    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 5    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
#
#                                         column_types  temporary
# 0  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 4                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 5                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False

# %%
from dlt.sources.rest_api import RESTAPIConfig, rest_api_source

config: RESTAPIConfig = {
    "client": {
        "base_url": "https://www.strava.com/api/v3/",
        "auth": {
            "token": ACCESS_TOKEN, # <--- we already configured access_token above
        },
        "paginator": OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    },
    "resources": [  # <--- list resources
        {
            "name": "activities",
            "endpoint": {
                "path": "athlete/activities",
            },
            "write_disposition": "replace",  # ✅ Merge mode
            #"primary_key": "id" 
        },
    ],
}

strava_source = rest_api_source(config)


pipeline_from_config = dlt.pipeline(
    pipeline_name="strava_rest_api_from_config",
    destination="duckdb",
    #dataset_name="rest_api_data",
    dev_mode=True,
)

load_info = pipeline_from_config.run(strava_source)

# %%
conn = duckdb.connect(f"strava_rest_api_from_config.duckdb")
conn.sql(f"SET search_path = 'strava_rest_api_from_config'")
conn.sql("DESCRIBE").df()
# Out:
#                        database
# 0   strava_rest_api_from_config  \
# 1   strava_rest_api_from_config
# 2   strava_rest_api_from_config
# 3   strava_rest_api_from_config
# 4   strava_rest_api_from_config
# 5   strava_rest_api_from_config
# 6   strava_rest_api_from_config
# 7   strava_rest_api_from_config
# 8   strava_rest_api_from_config
# 9   strava_rest_api_from_config
# 10  strava_rest_api_from_config
# 11  strava_rest_api_from_config
# 12  strava_rest_api_from_config
# 13  strava_rest_api_from_config
# 14  strava_rest_api_from_config
# 15  strava_rest_api_from_config
# 16  strava_rest_api_from_config
# 17  strava_rest_api_from_config
# 18  strava_rest_api_from_config
# 19  strava_rest_api_from_config
# 20  strava_rest_api_from_config
# 21  strava_rest_api_from_config
# 22  strava_rest_api_from_config
# 23  strava_rest_api_from_config
# 24  strava_rest_api_from_config
# 25  strava_rest_api_from_config
# 26  strava_rest_api_from_config
# 27  strava_rest_api_from_config
# 28  strava_rest_api_from_config
# 29  strava_rest_api_from_config
# 30  strava_rest_api_from_config
# 31  strava_rest_api_from_config
# 32  strava_rest_api_from_config
# 33  strava_rest_api_from_config
# 34  strava_rest_api_from_config
# 35  strava_rest_api_from_config
# 36  strava_rest_api_from_config
# 37  strava_rest_api_from_config
#
#                                                schema
# 0   strava_rest_api_from_config_dataset_2025051304...  \
# 1   strava_rest_api_from_config_dataset_2025051304...
# 2   strava_rest_api_from_config_dataset_2025051304...
# 3   strava_rest_api_from_config_dataset_2025051304...
# 4   strava_rest_api_from_config_dataset_2025051304...
# 5   strava_rest_api_from_config_dataset_2025051304...
# 6   strava_rest_api_from_config_dataset_2025051304...
# 7   strava_rest_api_from_config_dataset_2025051304...
# 8   strava_rest_api_from_config_dataset_2025051304...
# 9   strava_rest_api_from_config_dataset_2025051304...
# 10  strava_rest_api_from_config_dataset_2025051304...
# 11  strava_rest_api_from_config_dataset_2025051304...
# 12  strava_rest_api_from_config_dataset_2025051304...
# 13  strava_rest_api_from_config_dataset_2025051304...
# 14  strava_rest_api_from_config_dataset_2025051304...
# 15  strava_rest_api_from_config_dataset_2025051304...
# 16  strava_rest_api_from_config_dataset_2025051304...
# 17  strava_rest_api_from_config_dataset_2025051304...
# 18  strava_rest_api_from_config_dataset_2025051304...
# 19  strava_rest_api_from_config_dataset_2025051304...
# 20  strava_rest_api_from_config_dataset_2025052510...
# 21  strava_rest_api_from_config_dataset_2025052510...
# 22  strava_rest_api_from_config_dataset_2025052510...
# 23  strava_rest_api_from_config_dataset_2025052510...
# 24  strava_rest_api_from_config_dataset_2025052510...
# 25  strava_rest_api_from_config_dataset_2025052510...
# 26  strava_rest_api_from_config_dataset_2025052912...
# 27  strava_rest_api_from_config_dataset_2025052912...
# 28  strava_rest_api_from_config_dataset_2025052912...
# 29  strava_rest_api_from_config_dataset_2025052912...
# 30  strava_rest_api_from_config_dataset_2025052912...
# 31  strava_rest_api_from_config_dataset_2025052912...
# 32  strava_rest_api_from_config_dataset_2025053009...
# 33  strava_rest_api_from_config_dataset_2025053009...
# 34  strava_rest_api_from_config_dataset_2025053009...
# 35  strava_rest_api_from_config_dataset_2025053009...
# 36  strava_rest_api_from_config_dataset_2025053009...
# 37  strava_rest_api_from_config_dataset_2025053009...
#
#                         name
# 0                 _dlt_loads  \
# 1        _dlt_pipeline_state
# 2               _dlt_version
# 3                 activities
# 4     activities__end_latlng
# 5   activities__start_latlng
# 6               _dlt_version
# 7                 activities
# 8     activities__end_latlng
# 9   activities__start_latlng
# 10                _dlt_loads
# 11       _dlt_pipeline_state
# 12              _dlt_version
# 13                activities
# 14    activities__end_latlng
# 15  activities__start_latlng
# 16              _dlt_version
# 17                activities
# 18    activities__end_latlng
# 19  activities__start_latlng
# 20                _dlt_loads
# 21       _dlt_pipeline_state
# 22              _dlt_version
# 23                activities
# 24    activities__end_latlng
# 25  activities__start_latlng
# 26                _dlt_loads
# 27       _dlt_pipeline_state
# 28              _dlt_version
# 29                activities
# 30    activities__end_latlng
# 31  activities__start_latlng
# 32                _dlt_loads
# 33       _dlt_pipeline_state
# 34              _dlt_version
# 35                activities
# 36    activities__end_latlng
# 37  activities__start_latlng
#
#                                          column_names
# 0   [load_id, schema_name, status, inserted_at, sc...  \
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [resource_state, athlete__id, athlete__resourc...
# 4   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 5   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 6   [version, engine_version, inserted_at, schema_...
# 7   [resource_state, athlete__id, athlete__resourc...
# 8   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 9   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 10  [load_id, schema_name, status, inserted_at, sc...
# 11  [version, engine_version, pipeline_name, state...
# 12  [version, engine_version, inserted_at, schema_...
# 13  [resource_state, athlete__id, athlete__resourc...
# 14  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 15  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 16  [version, engine_version, inserted_at, schema_...
# 17  [resource_state, athlete__id, athlete__resourc...
# 18  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 19  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 20  [load_id, schema_name, status, inserted_at, sc...
# 21  [version, engine_version, pipeline_name, state...
# 22  [version, engine_version, inserted_at, schema_...
# 23  [resource_state, athlete__id, athlete__resourc...
# 24    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 25    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 26  [load_id, schema_name, status, inserted_at, sc...
# 27  [version, engine_version, pipeline_name, state...
# 28  [version, engine_version, inserted_at, schema_...
# 29  [resource_state, athlete__id, athlete__resourc...
# 30    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 31    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 32  [load_id, schema_name, status, inserted_at, sc...
# 33  [version, engine_version, pipeline_name, state...
# 34  [version, engine_version, inserted_at, schema_...
# 35  [resource_state, athlete__id, athlete__resourc...
# 36    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 37    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 4         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 5         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 6   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 7   [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 8         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 9         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 10  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 11  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 12  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 13  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 14        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 15        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 16  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 17  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 18        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 19        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 20  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 21  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 22  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 23  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 24                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 25                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 26  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 27  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 28  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 29  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 30                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 31                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 32  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 33  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 34  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 35  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 36                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 37                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
