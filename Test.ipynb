# %%
import requests
import json
import time
import os
import pandas as pd
import dlt
from dotenv import load_dotenv

# %%
# === CONFIGURATION ===
load_dotenv()
CLIENT_ID = os.getenv(f'CLIENT_ID')
CLIENT_SECRET = os.getenv(f'CLIENT_SECRET')

TOKENS_FILE = 'secrets/strava_tokens.json'

# %%
# === LOAD OR REFRESH TOKENS ===
def load_tokens():
    if os.path.exists(TOKENS_FILE):
        with open(TOKENS_FILE, 'r') as f:
            return json.load(f)
    else:
        raise FileNotFoundError("Token file not found. Authorize first and save your tokens.")

def save_tokens(tokens):
    with open(TOKENS_FILE, 'w') as f:
        json.dump(tokens, f)

def refresh_tokens(tokens):
    if time.time() > tokens['expires_at']:
        print("Access token expired. Refreshing...")
        response = requests.post("https://www.strava.com/oauth/token", data={
            'client_id': CLIENT_ID,
            'client_secret': CLIENT_SECRET,
            'grant_type': 'refresh_token',
            'refresh_token': tokens['refresh_token']
        })
        new_tokens = response.json()
        tokens.update({
            'access_token': new_tokens['access_token'],
            'refresh_token': new_tokens['refresh_token'],
            'expires_at': new_tokens['expires_at']
        })
        save_tokens(tokens)
    return tokens

# === GET ACTIVITIES ===
def get_activities(access_token, per_page=30):
    headers = {'Authorization': f"Bearer {access_token}"}
    page = 1

    while True:
        response = requests.get(
            'https://www.strava.com/api/v3/athlete/activities',
            headers=headers,
            params={'per_page': per_page, 'page': page}
        )
        data = response.json()

        if not data:
            break

        for activity in data:
            yield activity
        
        page += 1

# %% [raw]
# print(f'https://www.strava.com/oauth/authorize?client_id={CLIENT_ID}&response_type=code&redirect_uri=http://localhost/exchange_token&approval_prompt=force&scope=activity:read_all')

# %% [raw]
# ONE_TIME_CODE = input('Enter Your One Time Code: ')
#
# # One-time token exchange
# response = requests.post("https://www.strava.com/oauth/token", data={
#     'client_id': CLIENT_ID,
#     'client_secret': CLIENT_SECRET,
#     'code': ONE_TIME_CODE,
#     'grant_type': 'authorization_code'
# })
#
# tokens = response.json()
# save_tokens(tokens)

# %%
# === MAIN FLOW ===
tokens = load_tokens()
tokens = refresh_tokens(tokens)
ACCESS_TOKEN=tokens['access_token']

activities_generator = get_activities(ACCESS_TOKEN)

activities = [activity for activity in activities_generator]

# === DISPLAY RESULTS ===
# for act in activities:
#     print(f"{act['start_date'][:10]} - {act['name']} - {act['distance']/1000:.2f} km")

# %% [raw]
# import boto3
# from pprint import pprint
#
# # 1) Create a Redshift client in your region
# client = boto3.client("redshift", region_name="us-east-2")
#
# # 2) Enable the Data API on your cluster immediately
# resp = client.modify_cluster(
#     ClusterIdentifier="redshift-cluster-test",   # ← replace with your cluster’s identifier
#     EnableDataApi=True,
#     ApplyImmediately=True
# )
# print("ModifyCluster response:")
# pprint(resp)
#
# # 3) Confirm it’s enabled
# status = client.describe_clusters(
#     ClusterIdentifier="your-cluster-name"
# )["Clusters"][0]["DataApiClusterEnabled"]
# print("Data API enabled?", status)

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth
from dlt.sources.helpers.rest_client.paginators import OffsetPaginator

os.environ["ACCESS_TOKEN"] = ACCESS_TOKEN
@dlt.source
def strava_source(
    access_token=dlt.secrets.value
):
    client = RESTClient(
        base_url='https://www.strava.com/api/v3/',
        auth=BearerTokenAuth(token=access_token),
        paginator=OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    )

    @dlt.resource(
        write_disposition="replace",
        #primary_key="id",
    )
    def activities():
        for page in client.paginate("athlete/activities"):
            yield page

    return activities

    @dlt.resource(
        write_disposition="replace",
        #primary_key="id",
    )
    def athlete():
        for page in client.paginate("athlete"):
            yield page

    return athlete

# %%
pipeline = dlt.pipeline(
    pipeline_name="strava_to_s3",       # you can keep the same name if you like
    destination="filesystem",            # ← switch to filesystem
    dataset_name="strava_activities_s3"  # name for the S3 “folder” in your bucket
)
load_info = pipeline.run(strava_source(), loader_file_format = "csv")
print(load_info)
# Out:
# Pipeline strava_to_s3 load step completed in 6.03 seconds
# 1 load package(s) were loaded to destination filesystem and into dataset strava_activities_s3
# The filesystem destination used s3://billy-heidel-test-bucket location to store data
# Load package 1748215434.8727343 is LOADED and contains no failed jobs

# %%
pipeline = dlt.pipeline(
    pipeline_name="strava_rest_api",
    destination="redshift",
)
load_info = pipeline.run(strava_source())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pipeline = dlt.pipeline(
#       2     pipeline_name="strava_rest_api",
#       3     destination="redshift",
#       4 )
#       5 load_info = pipeline.run(strava_source())
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\inject.py:255, in with_config.<locals>.decorator.<locals>._wrap(*args, **kwargs)
#     253     config = last_config(**kwargs)
#     254 else:
# --> 255     config = resolve_config(bound_args, accept_partial_=accept_partial)
#     257 # call the function with resolved config
#     258 update_bound_args(bound_args, config, args, kwargs)
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\inject.py:183, in with_config.<locals>.decorator.<locals>.resolve_config(bound_args, accept_partial_)
#     180 # this may be called from many threads so section_context is thread affine
#     181 with inject_section(section_context, lock_context=lock_context_on_injection):
#     182     # print(f"RESOLVE CONF in inject: {f.__name__}: {section_context.sections} vs {sections} in {bound_args.arguments}")
# --> 183     return resolve_configuration(
#     184         config or SPEC(),
#     185         explicit_value=bound_args.arguments,
#     186         accept_partial=accept_partial_,
#     187     )
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\resolve.py:67, in resolve_configuration(config, sections, explicit_value, accept_partial)
#      64     else:
#      65         log_traces(None, config.__section__, type(config), explicit_value, None, traces)
# ---> 67 return _resolve_configuration(config, sections, (), explicit_value, accept_partial)
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\resolve.py:164, in _resolve_configuration(config, explicit_sections, embedded_sections, explicit_value, accept_partial)
#     162 # if native representation didn't fully resolve the config, we try to resolve field by field
#     163 if not config.is_resolved():
# --> 164     _resolve_config_fields(
#     165         config, explicit_value, explicit_sections, embedded_sections, accept_partial
#     166     )
#     167 # full configuration was resolved
#     168 config.resolve()
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\resolve.py:277, in _resolve_config_fields(config, explicit_values, explicit_sections, embedded_sections, accept_partial)
#     275                         raise
#     276         else:
# --> 277             current_value, traces = _resolve_config_field(
#     278                 key,
#     279                 hint,
#     280                 default_value,
#     281                 explicit_value,
#     282                 config,
#     283                 config.__section__,
#     284                 explicit_sections,
#     285                 embedded_sections,
#     286                 accept_partial,
#     287             )
#     288 else:
#     289     # set the trace for explicit none
#     290     traces = [LookupTrace("ExplicitValues", None, key, None)]
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\resolve.py:325, in _resolve_config_field(key, hint, default_value, explicit_value, config, config_sections, explicit_sections, embedded_sections, accept_partial)
#     322     traces: List[LookupTrace] = []
#     323 else:
#     324     # resolve key value via active providers passing the original hint ie. to preserve TSecretValue
# --> 325     value, traces = _resolve_single_value(
#     326         key, hint, inner_hint, config_sections, explicit_sections, embedded_sections
#     327     )
#     328     log_traces(config, key, hint, value, default_value, traces)
#     329 # contexts must be resolved as a whole
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\resolve.py:426, in _resolve_single_value(key, hint, inner_hint, config_section, explicit_sections, embedded_sections)
#     424 container = Container()
#     425 # get providers from container
# --> 426 providers_context = container[PluggableRunContext].providers
#     427 # we may be resolving context
#     428 if is_context_inner_hint(inner_hint):
#     429     # resolve context with context provider and do not look further
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\container.py:67, in Container.__getitem__(self, spec)
#      65 if item is None:
#      66     if spec.can_create_default:
# ---> 67         item = spec()
#      68         self._thread_setitem(context, spec, item)
#      69     else:
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\specs\pluggable_run_context.py:90, in PluggableRunContext.__init__(self, init_context, runtime_config)
#      87     self.context = init_context
#      88 else:
#      89     # autodetect run dir
# ---> 90     self._plug(run_dir=None)
#      91 self.providers = ConfigProvidersContainer(self.context.initial_providers())
#      92 self.runtime_config = runtime_config
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\specs\pluggable_run_context.py:161, in PluggableRunContext._plug(self, run_dir, runtime_kwargs)
#     158 def _plug(self, run_dir: Optional[str], runtime_kwargs: Dict[str, Any] = None) -> None:
#     159     from dlt.common.configuration import plugins
# --> 161     m = plugins.manager()
#     162     self.context = m.hook.plug_run_context(run_dir=run_dir, runtime_kwargs=runtime_kwargs)
#     163     assert self.context, "plug_run_context hook returned None"
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\plugins.py:47, in manager()
#      44 """Returns current plugin context"""
#      45 from .container import Container
# ---> 47 return Container()[PluginContext].manager
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\container.py:67, in Container.__getitem__(self, spec)
#      65 if item is None:
#      66     if spec.can_create_default:
# ---> 67         item = spec()
#      68         self._thread_setitem(context, spec, item)
#      69     else:
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\common\configuration\plugins.py:35, in PluginContext.__init__(self)
#      32 self.manager.register(run_context)
#      34 # cli
# ---> 35 from dlt.cli import plugins
#      37 self.manager.add_hookspecs(plugins)
#      38 self.manager.register(plugins)
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\cli\plugins.py:9
#       7 from dlt.common.configuration import plugins
#       8 from dlt.cli import SupportsCliCommand
# ----> 9 from dlt.cli.init_command import (
#      10     DEFAULT_VERIFIED_SOURCES_REPO,
#      11 )
#      12 from dlt.cli.exceptions import CliCommandException
#      13 from dlt.cli.command_wrappers import (
#      14     init_command_wrapper,
#      15     list_sources_command_wrapper,
#    (...)
#      21     ai_setup_command_wrapper,
#      22 )
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\cli\init_command.py:31
#      28 import dlt.reflection.names as n
#      29 from dlt.reflection.script_inspector import import_pipeline_script
# ---> 31 from dlt.cli import echo as fmt, pipeline_files as files_ops, source_detection
#      32 from dlt.cli import utils
#      33 from dlt.cli.config_toml_writer import WritableConfigValue, write_values
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\cli\pipeline_files.py:17
#      14 from dlt.common.reflection.utils import get_module_docstring
#      16 from dlt.cli import utils
# ---> 17 from dlt.cli.requirements import SourceRequirements
#      19 TSourceType = Literal["core", "verified", "template"]
#      21 SOURCES_INIT_INFO_ENGINE_VERSION = 1
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\dlt\cli\requirements.py:3
#       1 from typing import Sequence, List
#       2 from importlib.metadata import version as pkg_version
# ----> 3 from packaging.requirements import Requirement
#       5 from dlt.version import DLT_PKG_NAME
#       8 class SourceRequirements:
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\packaging\requirements.py:8
#       4 from __future__ import annotations
#       6 from typing import Any, Iterator
# ----> 8 from ._parser import parse_requirement as _parse_requirement
#       9 from ._tokenizer import ParserSyntaxError
#      10 from .markers import Marker, _normalize_extra_values
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\packaging\_parser.py:12
#       9 import ast
#      10 from typing import NamedTuple, Sequence, Tuple, Union
# ---> 12 from ._tokenizer import DEFAULT_RULES, Tokenizer
#      15 class Node:
#      16     def __init__(self, value: str) -> None:
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\packaging\_tokenizer.py:8
#       5 from dataclasses import dataclass
#       6 from typing import Iterator, NoReturn
# ----> 8 from .specifiers import Specifier
#      11 @dataclass
#      12 class Token:
#      13     name: str
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\packaging\specifiers.py:18
#      15 import re
#      16 from typing import Callable, Iterable, Iterator, TypeVar, Union
# ---> 18 from .utils import canonicalize_version
#      19 from .version import Version
#      21 UnparsedVersion = Union[Version, str]
#
# File c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\packaging\utils.py:12
#       9 from typing import NewType, Tuple, Union, cast
#      11 from .tags import Tag, parse_tag
# ---> 12 from .version import InvalidVersion, Version, _TrimmedRelease
#      14 BuildTag = Union[Tuple[()], Tuple[int, str]]
#      15 NormalizedName = NewType("NormalizedName", str)
#
# ImportError: cannot import name '_TrimmedRelease' from 'packaging.version' (c:\Users\Billy\AppData\Local\Programs\Python\Python310\lib\site-packages\packaging\version.py)

# %%
# Define a dlt pipeline with automatic normalization
pipeline = dlt.pipeline(
    destination="duckdb",
    pipeline_name="strava_rest_api",
)

# run the pipeline with the new resource
load_info = pipeline.run(strava_source())
# Out:
# 2025-05-25 18:11:49,296|[WARNING]|27880|13792|dlt|pipeline.py|_state_to_props:1615|The destination dlt.destinations.redshift:None in state differs from destination dlt.destinations.duckdb:duckdb in pipeline and will be ignored

# %%
pipeline.dataset(dataset_type="default").schema.data_table_names()
# Out:
# ['activities', 'activities__start_latlng', 'activities__end_latlng']

# %%
pipeline.dataset(dataset_type="default").activities.df()
# Out:
#     resource_state  athlete__id  athlete__resource_state             name
# 0                2    148269563                        1      Morning Run  \
# 1                2    148269563                        1   Afternoon Walk
# 2                2    148269563                        1     Evening Walk
# 3                2    148269563                        1      Morning Run
# 4                2    148269563                        1     Morning Walk
# ..             ...          ...                      ...              ...
# 66               2    148269563                        1      Evening Run
# 67               2    148269563                        1      Morning Run
# 68               2    148269563                        1      Morning Run
# 69               2    148269563                        1      Morning Run
# 70               2    148269563                        1  Morning Workout
#
#     distance  moving_time  elapsed_time  total_elevation_gain     type
# 0    10322.1         3604          3604                     0      Run  \
# 1     3073.0         2257          2257                  <NA>     Walk
# 2     2938.9         2295          2295                  <NA>     Walk
# 3     6449.6         1802          1802                     0      Run
# 4     1331.0          977           977                  <NA>     Walk
# ..       ...          ...           ...                   ...      ...
# 66     568.6         3321          3321                     0      Run
# 67    7129.3         2613          2613                     0      Run
# 68    5099.3         1533          1533                     0      Run
# 69    6040.3         1589          1589                     0      Run
# 70       0.0           92            92                     0  Workout
#
#    sport_type  ...  upload_id_str                        external_id
# 0         Run  ...    15569576686           garmin_ping_442179704735  \
# 1        Walk  ...    15562343689           garmin_ping_441973417210
# 2        Walk  ...    15552255364           garmin_ping_441687539687
# 3         Run  ...    15548044755           garmin_ping_441562438394
# 4        Walk  ...    15545900991           garmin_ping_441504033764
# ..        ...  ...            ...                                ...
# 66        Run  ...    14524948604           garmin_ping_410575511422
# 67        Run  ...    13310815861  stripped_garmin_ping_372336753957
# 68        Run  ...    13310815879  stripped_garmin_ping_372336753968
# 69        Run  ...    13310818837  stripped_garmin_ping_372336816902
# 70    Workout  ...    13310818836  stripped_garmin_ping_372336816738
#
#    from_accepted_tag pr_count  total_photo_count  has_kudoed
# 0              False        0                  0       False  \
# 1              False        0                  0       False
# 2              False        0                  0       False
# 3              False        0                  0       False
# 4              False        0                  0       False
# ..               ...      ...                ...         ...
# 66             False        0                  0       False
# 67             False        0                  0       False
# 68             False        0                  0       False
# 69             False        0                  0       False
# 70             False        0                  0       False
#
#           _dlt_load_id         _dlt_id  total_elevation_gain__v_double
# 0   1748211109.5374396  uloRQ/VC4hFJeQ                             NaN  \
# 1   1748211109.5374396  5oH6KyapF2SD+A                            20.1
# 2   1748211109.5374396  /z6SITkc/d7Gpw                             3.5
# 3   1748211109.5374396  72vGQRsLPPegRw                             NaN
# 4   1748211109.5374396  Zm9KXbInu/ASJw                             3.5
# ..                 ...             ...                             ...
# 66  1748211109.5374396  lA7cFgMk5WZqig                             NaN
# 67  1748211109.5374396  OOqr8seFpIHm1A                             NaN
# 68  1748211109.5374396  4Aks/ibXaI4W6w                             NaN
# 69  1748211109.5374396  bfcV72ad9QsG6A                             NaN
# 70  1748211109.5374396  l6hzZ6Fa6IlMKw                             NaN
#
#     workout_type
# 0           <NA>
# 1           <NA>
# 2           <NA>
# 3           <NA>
# 4           <NA>
# ..           ...
# 66          <NA>
# 67          <NA>
# 68          <NA>
# 69          <NA>
# 70          <NA>
#
# [71 rows x 50 columns]

# %%
import duckdb

conn = duckdb.connect(f"strava_rest_api.duckdb")
conn.sql(f"SET search_path = 'strava_rest_api'")
conn.sql("DESCRIBE").df()
# Out:
#           database                   schema                      name
# 0  strava_rest_api  strava_rest_api_dataset                _dlt_loads  \
# 1  strava_rest_api  strava_rest_api_dataset       _dlt_pipeline_state
# 2  strava_rest_api  strava_rest_api_dataset              _dlt_version
# 3  strava_rest_api  strava_rest_api_dataset                activities
# 4  strava_rest_api  strava_rest_api_dataset    activities__end_latlng
# 5  strava_rest_api  strava_rest_api_dataset  activities__start_latlng
#
#                                         column_names
# 0  [load_id, schema_name, status, inserted_at, sc...  \
# 1  [version, engine_version, pipeline_name, state...
# 2  [version, engine_version, inserted_at, schema_...
# 3  [resource_state, athlete__id, athlete__resourc...
# 4    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 5    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
#
#                                         column_types  temporary
# 0  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 4                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 5                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False

# %%
from dlt.sources.rest_api import RESTAPIConfig, rest_api_source

config: RESTAPIConfig = {
    "client": {
        "base_url": "https://www.strava.com/api/v3/",
        "auth": {
            "token": ACCESS_TOKEN, # <--- we already configured access_token above
        },
        "paginator": OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    },
    "resources": [  # <--- list resources
        {
            "name": "activities",
            "endpoint": {
                "path": "athlete/activities",
            },
            "write_disposition": "replace",  # ✅ Merge mode
            #"primary_key": "id" 
        },
    ],
}

strava_source = rest_api_source(config)


pipeline_from_config = dlt.pipeline(
    pipeline_name="strava_rest_api_from_config",
    destination="duckdb",
    #dataset_name="rest_api_data",
    dev_mode=True,
)

load_info = pipeline_from_config.run(strava_source)

# %%
conn = duckdb.connect(f"strava_rest_api_from_config.duckdb")
conn.sql(f"SET search_path = 'strava_rest_api_from_config'")
conn.sql("DESCRIBE").df()
# Out:
#                        database
# 0   strava_rest_api_from_config  \
# 1   strava_rest_api_from_config
# 2   strava_rest_api_from_config
# 3   strava_rest_api_from_config
# 4   strava_rest_api_from_config
# 5   strava_rest_api_from_config
# 6   strava_rest_api_from_config
# 7   strava_rest_api_from_config
# 8   strava_rest_api_from_config
# 9   strava_rest_api_from_config
# 10  strava_rest_api_from_config
# 11  strava_rest_api_from_config
# 12  strava_rest_api_from_config
# 13  strava_rest_api_from_config
# 14  strava_rest_api_from_config
# 15  strava_rest_api_from_config
# 16  strava_rest_api_from_config
# 17  strava_rest_api_from_config
# 18  strava_rest_api_from_config
# 19  strava_rest_api_from_config
# 20  strava_rest_api_from_config
# 21  strava_rest_api_from_config
# 22  strava_rest_api_from_config
# 23  strava_rest_api_from_config
# 24  strava_rest_api_from_config
# 25  strava_rest_api_from_config
#
#                                                schema
# 0   strava_rest_api_from_config_dataset_2025051304...  \
# 1   strava_rest_api_from_config_dataset_2025051304...
# 2   strava_rest_api_from_config_dataset_2025051304...
# 3   strava_rest_api_from_config_dataset_2025051304...
# 4   strava_rest_api_from_config_dataset_2025051304...
# 5   strava_rest_api_from_config_dataset_2025051304...
# 6   strava_rest_api_from_config_dataset_2025051304...
# 7   strava_rest_api_from_config_dataset_2025051304...
# 8   strava_rest_api_from_config_dataset_2025051304...
# 9   strava_rest_api_from_config_dataset_2025051304...
# 10  strava_rest_api_from_config_dataset_2025051304...
# 11  strava_rest_api_from_config_dataset_2025051304...
# 12  strava_rest_api_from_config_dataset_2025051304...
# 13  strava_rest_api_from_config_dataset_2025051304...
# 14  strava_rest_api_from_config_dataset_2025051304...
# 15  strava_rest_api_from_config_dataset_2025051304...
# 16  strava_rest_api_from_config_dataset_2025051304...
# 17  strava_rest_api_from_config_dataset_2025051304...
# 18  strava_rest_api_from_config_dataset_2025051304...
# 19  strava_rest_api_from_config_dataset_2025051304...
# 20  strava_rest_api_from_config_dataset_2025052510...
# 21  strava_rest_api_from_config_dataset_2025052510...
# 22  strava_rest_api_from_config_dataset_2025052510...
# 23  strava_rest_api_from_config_dataset_2025052510...
# 24  strava_rest_api_from_config_dataset_2025052510...
# 25  strava_rest_api_from_config_dataset_2025052510...
#
#                         name
# 0                 _dlt_loads  \
# 1        _dlt_pipeline_state
# 2               _dlt_version
# 3                 activities
# 4     activities__end_latlng
# 5   activities__start_latlng
# 6               _dlt_version
# 7                 activities
# 8     activities__end_latlng
# 9   activities__start_latlng
# 10                _dlt_loads
# 11       _dlt_pipeline_state
# 12              _dlt_version
# 13                activities
# 14    activities__end_latlng
# 15  activities__start_latlng
# 16              _dlt_version
# 17                activities
# 18    activities__end_latlng
# 19  activities__start_latlng
# 20                _dlt_loads
# 21       _dlt_pipeline_state
# 22              _dlt_version
# 23                activities
# 24    activities__end_latlng
# 25  activities__start_latlng
#
#                                          column_names
# 0   [load_id, schema_name, status, inserted_at, sc...  \
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [resource_state, athlete__id, athlete__resourc...
# 4   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 5   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 6   [version, engine_version, inserted_at, schema_...
# 7   [resource_state, athlete__id, athlete__resourc...
# 8   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 9   [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 10  [load_id, schema_name, status, inserted_at, sc...
# 11  [version, engine_version, pipeline_name, state...
# 12  [version, engine_version, inserted_at, schema_...
# 13  [resource_state, athlete__id, athlete__resourc...
# 14  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 15  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 16  [version, engine_version, inserted_at, schema_...
# 17  [resource_state, athlete__id, athlete__resourc...
# 18  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 19  [value, _dlt_root_id, _dlt_parent_id, _dlt_lis...
# 20  [load_id, schema_name, status, inserted_at, sc...
# 21  [version, engine_version, pipeline_name, state...
# 22  [version, engine_version, inserted_at, schema_...
# 23  [resource_state, athlete__id, athlete__resourc...
# 24    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 25    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 4         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 5         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 6   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 7   [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 8         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 9         [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 10  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 11  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 12  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 13  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 14        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 15        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 16  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 17  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 18        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 19        [DOUBLE, VARCHAR, VARCHAR, BIGINT, VARCHAR]      False
# 20  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 21  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 22  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 23  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 24                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 25                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
