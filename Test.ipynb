# %%
import requests
import json
import time
import os
import pandas as pd
import dlt
from dotenv import load_dotenv

# %%
# === CONFIGURATION ===
load_dotenv()
CLIENT_ID = os.getenv(f'CLIENT_ID')
CLIENT_SECRET = os.getenv(f'CLIENT_SECRET')

TOKENS_FILE = 'secrets/strava_tokens.json'

# %%
# === LOAD OR REFRESH TOKENS ===
def load_tokens():
    if os.path.exists(TOKENS_FILE):
        with open(TOKENS_FILE, 'r') as f:
            return json.load(f)
    else:
        raise FileNotFoundError("Token file not found. Authorize first and save your tokens.")

def save_tokens(tokens):
    with open(TOKENS_FILE, 'w') as f:
        json.dump(tokens, f)

def refresh_tokens(tokens):
    if time.time() > tokens['expires_at']:
        print("Access token expired. Refreshing...")
        response = requests.post("https://www.strava.com/oauth/token", data={
            'client_id': CLIENT_ID,
            'client_secret': CLIENT_SECRET,
            'grant_type': 'refresh_token',
            'refresh_token': tokens['refresh_token']
        })
        new_tokens = response.json()
        tokens.update({
            'access_token': new_tokens['access_token'],
            'refresh_token': new_tokens['refresh_token'],
            'expires_at': new_tokens['expires_at']
        })
        save_tokens(tokens)
    return tokens

# === GET ACTIVITIES ===
def get_activities(access_token, per_page=30):
    headers = {'Authorization': f"Bearer {access_token}"}
    page = 1

    while True:
        response = requests.get(
            'https://www.strava.com/api/v3/athlete/activities',
            headers=headers,
            params={'per_page': per_page, 'page': page}
        )
        data = response.json()

        if not data:
            break

        for activity in data:
            yield activity
        
        page += 1

# %% [raw]
# print(f'https://www.strava.com/oauth/authorize?client_id={CLIENT_ID}&response_type=code&redirect_uri=http://localhost/exchange_token&approval_prompt=force&scope=activity:read_all')

# %% [raw]
# ONE_TIME_CODE = input('Enter Your One Time Code: ')
#
# # One-time token exchange
# response = requests.post("https://www.strava.com/oauth/token", data={
#     'client_id': CLIENT_ID,
#     'client_secret': CLIENT_SECRET,
#     'code': ONE_TIME_CODE,
#     'grant_type': 'authorization_code'
# })
#
# tokens = response.json()
# save_tokens(tokens)

# %%
# === MAIN FLOW ===
tokens = load_tokens()
tokens = refresh_tokens(tokens)
ACCESS_TOKEN=tokens['access_token']

activities_generator = get_activities(ACCESS_TOKEN)

activities = [activity for activity in activities_generator]

# === DISPLAY RESULTS ===
for act in activities:
    print(f"{act['start_date'][:10]} - {act['name']} - {act['distance']/1000:.2f} km")
# Out:
# 2025-05-02 - Morning Run - 6.43 km
# 2025-05-02 - Morning Walk - 1.33 km
# 2025-04-30 - Morning Run - 4.53 km
# 2025-04-30 - Morning Walk - 1.30 km
# 2025-04-29 - Morning Run - 6.44 km
# 2025-04-29 - Morning Walk - 1.31 km
# 2025-04-28 - Morning Walk - 1.32 km
# 2025-04-27 - Morning Run - 6.44 km
# 2025-04-26 - Evening Walk - 1.72 km
# 2025-04-25 - Morning Run - 6.46 km
# 2025-04-25 - Morning Walk - 1.30 km
# 2025-04-23 - Evening Run - 1.77 km
# 2025-04-23 - Morning Walk - 1.33 km
# 2025-04-22 - Morning Run - 6.44 km
# 2025-04-20 - Lunch Run - 9.65 km
# 2025-04-19 - Morning Run - 6.11 km
# 2025-04-18 - Morning Walk - 1.32 km
# 2025-04-16 - Morning Run - 4.97 km
# 2025-04-15 - Morning Run - 6.44 km
# 2025-04-15 - Morning Walk - 1.33 km
# 2025-04-14 - Morning Walk - 1.21 km
# 2025-04-13 - Lunch Run - 9.25 km
# 2025-04-12 - Morning Run - 10.50 km
# 2025-04-04 - Afternoon Run - 10.19 km
# 2025-04-02 - Morning Run - 6.52 km
# 2025-04-01 - Morning Run - 10.38 km
# 2025-03-31 - Morning Run - 9.88 km
# 2025-03-28 - Morning Run - 10.79 km
# 2025-03-27 - Morning Run - 4.25 km
# 2025-03-26 - Morning Run - 5.94 km
# 2025-02-22 - Morning Run - 16.21 km
# 2025-02-21 - Morning Run - 11.15 km
# 2025-02-20 - Evening Walk - 1.66 km
# 2025-02-19 - Morning Run - 7.41 km
# 2025-02-14 - Evening Walk - 0.30 km
# 2025-02-12 - Evening Run - 0.57 km
# 2024-09-01 - Morning Run - 7.13 km
# 2024-06-22 - Morning Run - 5.10 km
# 2024-06-15 - Morning Run - 6.04 km
# 2024-03-27 - Morning Workout - 0.00 km

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\william.heidel\\AppData\\Roaming',
#         'APPLICATIONINSIGHTS_CONFIGURATION_CONTENT': '{}',
#         'APPLICATION_INSIGHTS_NO_DIAGNOSTIC_CHANNEL': '1',
#         'CHOCOLATEYINSTALL': 'C:\\ProgramData\\chocolatey',
#         'CHOCOLATEYLASTPATHUPDATE': '133586205342552078',
#         'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_23700_TSVXPBQNOLKTIWJJ',
#         'CLIENT_ID': '157579',
#         'CLIENT_SECRET': 'cbe88340d741962bc1e2a56e64b10e643c00dd83',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPONENT_INSTALLER_DIR': 'C:\\Users\\william.heidel\\AppData\\Local\\Microsoft\\Edge\\User Data',
#         'COMPUTERNAME': 'CR-XLT798YPN3',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'CONDA_PREFIX': 'C:\\Users\\william.heidel\\.conda\\envs\\blob',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'EDGE_BROWSER_PID': '15920',
#         'EDGE_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_15920_HSGCYHLVZRYDHASH',
#         'EDGE_METRICS_CLIENT_ID_HASH': '-5968230238782688387',
#         'EDGE_METRICS_SESSION_ID': '451',
#         'EDGE_RUNTIME_VARIATIONS_SEED_ETAG': '"cJlW46SDMZqxC+l3CmiBTqtzZwwMyvxrHNgPII1EM7Q="',
#         'EDGE_USER_DATA_DIR': 'C:\\Users\\william.heidel\\AppData\\Local\\Microsoft\\Edge\\User Data',
#         'EDGE_UX_CONFIG_CORRELATION_ID': '47DEQpj8HBSa+/TImW+5JCeuQeRkm5NMpJWZG3hSuFU=',
#         'EDGE_VARIATIONS_SEED_ETAG': '"OVP8zaLitXnCJDnb+lAG43i7zoLnMUU7XIYI6X3hzjY="',
#         'EFC_13220': '1',
#         'ELECTRON_RUN_AS_NODE': '1',
#         'FPS_BROWSER_APP_PROFILE_STRING': 'Internet Explorer',
#         'FPS_BROWSER_USER_PROFILE_STRING': 'Default',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\william.heidel',
#         'IGCCSVC_DB': '...',
#         'JPY_INTERRUPT_EVENT': '1768',
#         'JUPYTER_CONFIG_DATA': 'c:\\Users\\william.heidel\\.vscode\\extensions\\ms-toolsai.vscode-ai-remote-1.4.1\\dist\\src\\jupyterConfigData.json',
#         'LOCALAPPDATA': 'C:\\Users\\william.heidel\\AppData\\Local',
#         'LOGONSERVER': '\\\\C00001PADC010',
#         'NUMBER_OF_PROCESSORS': '16',
#         'ONEDRIVE': 'C:\\Users\\william.heidel\\OneDrive - CLEAResult Consulting Inc',
#         'ONEDRIVECOMMERCIAL': 'C:\\Users\\william.heidel\\OneDrive - CLEAResult Consulting Inc',
#         'ORIGINAL_XDG_CURRENT_DESKTOP': 'undefined',
#         'OS': 'Windows_NT',
#         'PATH': 'c:\\Users\\william.heidel\\.conda\\envs\\blob;C:\\Program Files (x86)\\Microsoft\\Edge\\Application;C:\\Program Files\\OpenLogic\\jdk-21.0.4.7-hotspot\\bin;C:\\Program Files\\OpenLogic\\jdk-11.0.24.8-hotspot\\bin;C:\\Program Files\\OpenLogic\\jdk-17.0.12.7-hotspot\\bin;C:\\Program Files\\OpenLogic\\jdk-8.0.422.05-hotspot\\bin;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\ServiceNow;C:\\Program Files (x86)\\Microsoft SQL Server\\160\\DTS\\Binn\\;C:\\Program Files\\dotnet\\;C:\\Program Files (x86)\\dotnet-core-uninstall\\;C:\\Users\\william.heidel\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\william.heidel\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\william.heidel\\AppData\\Local\\Programs\\Azure Data Studio\\bin;C:\\Users\\william.heidel\\AppData\\Local\\Programs\\Git\\cmd;;C:\\Program Files (x86)\\Microsoft\\Edge\\Application;C:\\Program Files\\OpenLogic\\jdk-21.0.4.7-hotspot\\bin;C:\\Program Files\\OpenLogic\\jdk-11.0.24.8-hotspot\\bin;C:\\Program Files\\OpenLogic\\jdk-17.0.12.7-hotspot\\bin;C:\\Program Files\\OpenLogic\\jdk-8.0.422.05-hotspot\\bin;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\ServiceNow;C:\\Program Files (x86)\\Microsoft SQL Server\\160\\DTS\\Binn\\;C:\\Program Files\\dotnet\\;C:\\Program Files (x86)\\dotnet-core-uninstall\\;C:\\Users\\william.heidel\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\william.heidel\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\william.heidel\\AppData\\Local\\Programs\\Azure Data Studio\\bin;C:\\Users\\william.heidel\\AppData\\Local\\Programs\\Git\\cmd;',
#         'PATHEXT': '.COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC',
#         'PROCESSOR_ARCHITECTURE': 'AMD64',
#         'PROCESSOR_IDENTIFIER': 'Intel64 Family 6 Model 141 Stepping 1, GenuineIntel',
#         'PROCESSOR_LEVEL': '6',
#         'PROCESSOR_REVISION': '8d01',
#         'PROGRAMDATA': 'C:\\ProgramData',
#         'PROGRAMFILES': 'C:\\Program Files',
#         'PROGRAMFILES(X86)': 'C:\\Program Files (x86)',
#         'PROGRAMW6432': 'C:\\Program Files',
#         'PSMODULEPATH': 'C:\\Program Files\\WindowsPowerShell\\Modules;C:\\WINDOWS\\system32\\WindowsPowerShell\\v1.0\\Modules',
#         'PUBLIC': 'C:\\Users\\Public',
#         'PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING': '1',
#         'PYTHONIOENCODING': 'utf-8',
#         'PYTHONUNBUFFERED': '1',
#         'PYTHON_FROZEN_MODULES': 'on',
#         'SESSIONNAME': 'Console',
#         'SYSTEMDRIVE': 'C:',
#         'SYSTEMROOT': 'C:\\WINDOWS',
#         'TEMP': 'C:\\Users\\WILLIA~1.HEI\\AppData\\Local\\Temp',
#         'TMP': 'C:\\Users\\WILLIA~1.HEI\\AppData\\Local\\Temp',
#         'UATDATA': 'C:\\WINDOWS\\CCM\\UATData\\D9F8C395-CAB8-491d-B8AC-179A1FE1BE77',
#         'USERDNSDOMAIN': 'CLEARESULT.COM',
#         'USERDOMAIN': 'CLEARESULT',
#         'USERDOMAIN_ROAMINGPROFILE': 'CLEARESULT',
#         'USERNAME': 'william.heidel',
#         'USERPROFILE': 'C:\\Users\\william.heidel',
#         'VSCODE_CODE_CACHE_PATH': 'C:\\Users\\william.heidel\\AppData\\Roaming\\Code\\CachedData\\17baf841131aa23349f217ca7c570c76ee87b957',
#         'VSCODE_CRASH_REPORTER_PROCESS_TYPE': 'extensionHost',
#         'VSCODE_CWD': 'C:\\WINDOWS\\system32',
#         'VSCODE_ESM_ENTRYPOINT': 'vs/workbench/api/node/extensionHostProcess',
#         'VSCODE_HANDLES_UNCAUGHT_ERRORS': 'true',
#         'VSCODE_IPC_HOOK': '\\\\.\\pipe\\73cb7d91-1.99.3-main-sock',
#         'VSCODE_L10N_BUNDLE_LOCATION': '',
#         'VSCODE_NLS_CONFIG': '{"userLocale":"en-us","osLocale":"en-us","resolvedLanguage":"en","defaultMessagesFile":"C:\\\\Users\\\\william.heidel\\\\AppData\\\\Local\\\\Programs\\\\Microsoft VS Code\\\\resources\\\\app\\\\out\\\\nls.messages.json","locale":"en-us","availableLanguages":{}}',
#         'VSCODE_PID': '23700',
#         'WINDIR': 'C:\\WINDOWS',
#         'ZES_ENABLE_SYSMAN': '1',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'TERM': 'xterm-color',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth
from dlt.sources.helpers.rest_client.paginators import OffsetPaginator

os.environ["ACCESS_TOKEN"] = ACCESS_TOKEN
@dlt.resource(name="activities")
def paginated_getter(
    access_token=dlt.secrets.value,
):
    client = RESTClient(
        base_url='https://www.strava.com/api/v3/',
        auth=BearerTokenAuth(token=access_token),
        paginator=OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    )

    for page in client.paginate("athlete/activities"):
        for activity in page:
            yield activity

# Run the pull
for activity in paginated_getter():
    print(f"{activity['start_date'][:10]} - {activity['name']} - {activity['distance']/1000:.2f} km")
# Out:
# 2025-05-02 - Morning Run - 6.43 km
# 2025-05-02 - Morning Walk - 1.33 km
# 2025-04-30 - Morning Run - 4.53 km
# 2025-04-30 - Morning Walk - 1.30 km
# 2025-04-29 - Morning Run - 6.44 km
# 2025-04-29 - Morning Walk - 1.31 km
# 2025-04-28 - Morning Walk - 1.32 km
# 2025-04-27 - Morning Run - 6.44 km
# 2025-04-26 - Evening Walk - 1.72 km
# 2025-04-25 - Morning Run - 6.46 km
# 2025-04-25 - Morning Walk - 1.30 km
# 2025-04-23 - Evening Run - 1.77 km
# 2025-04-23 - Morning Walk - 1.33 km
# 2025-04-22 - Morning Run - 6.44 km
# 2025-04-20 - Lunch Run - 9.65 km
# 2025-04-19 - Morning Run - 6.11 km
# 2025-04-18 - Morning Walk - 1.32 km
# 2025-04-16 - Morning Run - 4.97 km
# 2025-04-15 - Morning Run - 6.44 km
# 2025-04-15 - Morning Walk - 1.33 km
# 2025-04-14 - Morning Walk - 1.21 km
# 2025-04-13 - Lunch Run - 9.25 km
# 2025-04-12 - Morning Run - 10.50 km
# 2025-04-04 - Afternoon Run - 10.19 km
# 2025-04-02 - Morning Run - 6.52 km
# 2025-04-01 - Morning Run - 10.38 km
# 2025-03-31 - Morning Run - 9.88 km
# 2025-03-28 - Morning Run - 10.79 km
# 2025-03-27 - Morning Run - 4.25 km
# 2025-03-26 - Morning Run - 5.94 km
# 2025-02-22 - Morning Run - 16.21 km
# 2025-02-21 - Morning Run - 11.15 km
# 2025-02-20 - Evening Walk - 1.66 km
# 2025-02-19 - Morning Run - 7.41 km
# 2025-02-14 - Evening Walk - 0.30 km
# 2025-02-12 - Evening Run - 0.57 km
# 2024-09-01 - Morning Run - 7.13 km
# 2024-06-22 - Morning Run - 5.10 km
# 2024-06-15 - Morning Run - 6.04 km
# 2024-03-27 - Morning Workout - 0.00 km
