# %%
import requests
import json
import time
import os
import pandas as pd
import dlt
from dlt.sources.filesystem import filesystem
from dotenv import load_dotenv

# %%
# === CONFIGURATION ===
load_dotenv()
CLIENT_ID = os.getenv(f'CLIENT_ID')
CLIENT_SECRET = os.getenv(f'CLIENT_SECRET')

TOKENS_FILE = 'secrets/strava_tokens.json'

# %%
# === LOAD OR REFRESH TOKENS ===
def load_tokens():
    if os.path.exists(TOKENS_FILE):
        with open(TOKENS_FILE, 'r') as f:
            return json.load(f)
    else:
        raise FileNotFoundError("Token file not found. Authorize first and save your tokens.")

def save_tokens(tokens):
    with open(TOKENS_FILE, 'w') as f:
        json.dump(tokens, f)

def refresh_tokens(tokens):
    if time.time() > tokens['expires_at']:
        print("Access token expired. Refreshing...")
        response = requests.post("https://www.strava.com/oauth/token", data={
            'client_id': CLIENT_ID,
            'client_secret': CLIENT_SECRET,
            'grant_type': 'refresh_token',
            'refresh_token': tokens['refresh_token']
        })
        new_tokens = response.json()
        tokens.update({
            'access_token': new_tokens['access_token'],
            'refresh_token': new_tokens['refresh_token'],
            'expires_at': new_tokens['expires_at']
        })
        save_tokens(tokens)
    return tokens

# === GET ACTIVITIES ===
def get_activities(access_token, per_page=30):
    headers = {'Authorization': f"Bearer {access_token}"}
    page = 1

    while True:
        response = requests.get(
            'https://www.strava.com/api/v3/athlete/activities',
            headers=headers,
            params={'per_page': per_page, 'page': page}
        )
        data = response.json()

        if not data:
            break

        for activity in data:
            yield activity
        
        page += 1

# %% [raw]
# print(f'https://www.strava.com/oauth/authorize?client_id={CLIENT_ID}&response_type=code&redirect_uri=http://localhost/exchange_token&approval_prompt=force&scope=activity:read_all')

# %% [raw]
# ONE_TIME_CODE = input('Enter Your One Time Code: ')
#
# # One-time token exchange
# response = requests.post("https://www.strava.com/oauth/token", data={
#     'client_id': CLIENT_ID,
#     'client_secret': CLIENT_SECRET,
#     'code': ONE_TIME_CODE,
#     'grant_type': 'authorization_code'
# })
#
# tokens = response.json()
# save_tokens(tokens)

# %%
# === MAIN FLOW ===
tokens = load_tokens()
tokens = refresh_tokens(tokens)
ACCESS_TOKEN=tokens['access_token']

activities_generator = get_activities(ACCESS_TOKEN)

activities = [activity for activity in activities_generator]

# === DISPLAY RESULTS ===
# for act in activities:
#     print(f"{act['start_date'][:10]} - {act['name']} - {act['distance']/1000:.2f} km")

# %% [raw]
# import boto3
# from pprint import pprint
#
# # 1) Create a Redshift client in your region
# client = boto3.client("redshift", region_name="us-east-2")
#
# # 2) Enable the Data API on your cluster immediately
# resp = client.modify_cluster(
#     ClusterIdentifier="redshift-cluster-test",   # ← replace with your cluster’s identifier
#     EnableDataApi=True,
#     ApplyImmediately=True
# )
# print("ModifyCluster response:")
# pprint(resp)
#
# # 3) Confirm it’s enabled
# status = client.describe_clusters(
#     ClusterIdentifier="your-cluster-name"
# )["Clusters"][0]["DataApiClusterEnabled"]
# print("Data API enabled?", status)

# %%
import dlt
from dlt.sources.helpers.rest_client import RESTClient
from dlt.sources.helpers.rest_client.auth import BearerTokenAuth
from dlt.sources.helpers.rest_client.paginators import OffsetPaginator

os.environ["ACCESS_TOKEN"] = ACCESS_TOKEN
@dlt.source
def strava_source(
    access_token=dlt.secrets.value
):
    client = RESTClient(
        base_url='https://www.strava.com/api/v3/',
        auth=BearerTokenAuth(token=access_token),
        paginator=OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    )

    @dlt.resource(
        write_disposition="replace",
        #primary_key="id",
    )
    def activities():
        for page in client.paginate("athlete/activities"):
            yield page

    return activities

    @dlt.resource(
        write_disposition="replace",
        #primary_key="id",
    )
    def athlete():
        for page in client.paginate("athlete"):
            yield page

    return athlete

# %%
pipeline_s3 = dlt.pipeline(
    pipeline_name="strava_to_s3",       # you can keep the same name if you like
    destination="filesystem",            # ← switch to filesystem
    dataset_name="strava_activities_s3"  # name for the S3 “folder” in your bucket
)
load_info_s3 = pipeline_s3.run(strava_source(), loader_file_format = "csv")
#print(load_info_s3)

# %%
pipeline_redshift = dlt.pipeline(
    pipeline_name="strava_s3_to_redshift",
    destination="redshift",
    dataset_name="strava_rest_api_dataset"
)

source_from_s3 = filesystem(
    bucket_url="s3://billy-heidel-test-bucket/strava_activities_s3",
    file_glob="**/*.csv"
)

# Run pipeline to move CSV data from S3 into Redshift
load_info_redshift = pipeline_redshift.run(source_from_s3)
#print("Loaded to Redshift:", load_info_redshift)

# %%
pipeline = dlt.pipeline(
    pipeline_name="strava_rest_api_redshift",
    destination="redshift",
)
#load_info = pipeline.run(strava_source())

# %%
# Define a dlt pipeline with automatic normalization
pipeline = dlt.pipeline(
    destination="duckdb",
    pipeline_name="strava_rest_api",
)

# run the pipeline with the new resource
load_info = pipeline.run(strava_source())

# %%
pipeline.dataset(dataset_type="default").schema.data_table_names()
# Out:
# ['activities', 'activities__start_latlng', 'activities__end_latlng']

# %%
pipeline.dataset(dataset_type="default").activities.df()
# Out:
#     resource_state  athlete__id  athlete__resource_state             name
# 0                2    148269563                        1     Morning Walk  \
# 1                2    148269563                        1     Morning Walk
# 2                2    148269563                        1      Morning Run
# 3                2    148269563                        1   Afternoon Walk
# 4                2    148269563                        1     Evening Walk
# ..             ...          ...                      ...              ...
# 68               2    148269563                        1      Evening Run
# 69               2    148269563                        1      Morning Run
# 70               2    148269563                        1      Morning Run
# 71               2    148269563                        1      Morning Run
# 72               2    148269563                        1  Morning Workout
#
#     distance  moving_time  elapsed_time  total_elevation_gain     type
# 0     1166.9          897           897                   9.7     Walk  \
# 1     1422.2          938           938                  14.5     Walk
# 2    10322.1         3604          3604                   0.0      Run
# 3     3073.0         2257          2257                  20.1     Walk
# 4     2938.9         2295          2295                   3.5     Walk
# ..       ...          ...           ...                   ...      ...
# 68     568.6         3321          3321                   0.0      Run
# 69    7129.3         2613          2613                   0.0      Run
# 70    5099.3         1533          1533                   0.0      Run
# 71    6040.3         1589          1589                   0.0      Run
# 72       0.0           92            92                   0.0  Workout
#
#    sport_type  ...    upload_id upload_id_str
# 0        Walk  ...  15588803482   15588803482  \
# 1        Walk  ...  15579558715   15579558715
# 2         Run  ...  15569576686   15569576686
# 3        Walk  ...  15562343689   15562343689
# 4        Walk  ...  15552255364   15552255364
# ..        ...  ...          ...           ...
# 68        Run  ...  14524948604   14524948604
# 69        Run  ...  13310815861   13310815861
# 70        Run  ...  13310815879   13310815879
# 71        Run  ...  13310818837   13310818837
# 72    Workout  ...  13310818836   13310818836
#
#                           external_id from_accepted_tag  pr_count
# 0            garmin_ping_442780035147             False         0  \
# 1            garmin_ping_442500649377             False         0
# 2            garmin_ping_442179704735             False         0
# 3            garmin_ping_441973417210             False         0
# 4            garmin_ping_441687539687             False         0
# ..                                ...               ...       ...
# 68           garmin_ping_410575511422             False         0
# 69  stripped_garmin_ping_372336753957             False         0
# 70  stripped_garmin_ping_372336753968             False         0
# 71  stripped_garmin_ping_372336816902             False         0
# 72  stripped_garmin_ping_372336816738             False         0
#
#     total_photo_count  has_kudoed       _dlt_load_id         _dlt_id
# 0                   0       False  1748357662.911686  h5F+Z1fgWJ2fhg  \
# 1                   0       False  1748357662.911686  Vf0QsiNoieA8Tg
# 2                   0       False  1748357662.911686  +NkyQVWQLdguhg
# 3                   0       False  1748357662.911686  jaXXp0PXtgHFHw
# 4                   0       False  1748357662.911686  YxDN69Gbsf2ovg
# ..                ...         ...                ...             ...
# 68                  0       False  1748357662.911686  lgVo4eM//dOosw
# 69                  0       False  1748357662.911686  t6/td0iUhC+0xQ
# 70                  0       False  1748357662.911686  mgR/smeZ3RT76Q
# 71                  0       False  1748357662.911686  5L3vT0c/AGNH3g
# 72                  0       False  1748357662.911686  kHiJ8F+8BN2RLg
#
#     workout_type
# 0           <NA>
# 1           <NA>
# 2           <NA>
# 3           <NA>
# 4           <NA>
# ..           ...
# 68          <NA>
# 69          <NA>
# 70          <NA>
# 71          <NA>
# 72          <NA>
#
# [73 rows x 49 columns]

# %%
import duckdb

conn = duckdb.connect(f"strava_rest_api.duckdb")
conn.sql(f"SET search_path = 'strava_rest_api'")
conn.sql("DESCRIBE").df()
# Out:
#           database                   schema                      name
# 0  strava_rest_api  strava_rest_api_dataset                _dlt_loads  \
# 1  strava_rest_api  strava_rest_api_dataset       _dlt_pipeline_state
# 2  strava_rest_api  strava_rest_api_dataset              _dlt_version
# 3  strava_rest_api  strava_rest_api_dataset                activities
# 4  strava_rest_api  strava_rest_api_dataset    activities__end_latlng
# 5  strava_rest_api  strava_rest_api_dataset  activities__start_latlng
#
#                                         column_names
# 0  [load_id, schema_name, status, inserted_at, sc...  \
# 1  [version, engine_version, pipeline_name, state...
# 2  [version, engine_version, inserted_at, schema_...
# 3  [resource_state, athlete__id, athlete__resourc...
# 4    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 5    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
#
#                                         column_types  temporary
# 0  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 4                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 5                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False

# %%
from dlt.sources.rest_api import RESTAPIConfig, rest_api_source

config: RESTAPIConfig = {
    "client": {
        "base_url": "https://www.strava.com/api/v3/",
        "auth": {
            "token": ACCESS_TOKEN, # <--- we already configured access_token above
        },
        "paginator": OffsetPaginator(
            limit=100,
            limit_param='per_page',
            offset=1,
            offset_param='page',
            stop_after_empty_page=True,
            total_path=None
        )
    },
    "resources": [  # <--- list resources
        {
            "name": "activities",
            "endpoint": {
                "path": "athlete/activities",
            },
            "write_disposition": "replace",  # ✅ Merge mode
            #"primary_key": "id" 
        },
    ],
}

strava_source = rest_api_source(config)


pipeline_from_config = dlt.pipeline(
    pipeline_name="strava_rest_api_from_config",
    destination="duckdb",
    #dataset_name="rest_api_data",
    dev_mode=True,
)

load_info = pipeline_from_config.run(strava_source)

# %%
conn = duckdb.connect(f"strava_rest_api_from_config.duckdb")
conn.sql(f"SET search_path = 'strava_rest_api_from_config'")
conn.sql("DESCRIBE").df()
# Out:
#                        database
# 0   strava_rest_api_from_config  \
# 1   strava_rest_api_from_config
# 2   strava_rest_api_from_config
# 3   strava_rest_api_from_config
# 4   strava_rest_api_from_config
# 5   strava_rest_api_from_config
# 6   strava_rest_api_from_config
# 7   strava_rest_api_from_config
# 8   strava_rest_api_from_config
# 9   strava_rest_api_from_config
# 10  strava_rest_api_from_config
# 11  strava_rest_api_from_config
# 12  strava_rest_api_from_config
# 13  strava_rest_api_from_config
# 14  strava_rest_api_from_config
# 15  strava_rest_api_from_config
# 16  strava_rest_api_from_config
# 17  strava_rest_api_from_config
#
#                                                schema
# 0   strava_rest_api_from_config_dataset_2025052702...  \
# 1   strava_rest_api_from_config_dataset_2025052702...
# 2   strava_rest_api_from_config_dataset_2025052702...
# 3   strava_rest_api_from_config_dataset_2025052702...
# 4   strava_rest_api_from_config_dataset_2025052702...
# 5   strava_rest_api_from_config_dataset_2025052702...
# 6   strava_rest_api_from_config_dataset_2025052702...
# 7   strava_rest_api_from_config_dataset_2025052702...
# 8   strava_rest_api_from_config_dataset_2025052702...
# 9   strava_rest_api_from_config_dataset_2025052702...
# 10  strava_rest_api_from_config_dataset_2025052702...
# 11  strava_rest_api_from_config_dataset_2025052702...
# 12  strava_rest_api_from_config_dataset_2025052702...
# 13  strava_rest_api_from_config_dataset_2025052702...
# 14  strava_rest_api_from_config_dataset_2025052702...
# 15  strava_rest_api_from_config_dataset_2025052702...
# 16  strava_rest_api_from_config_dataset_2025052702...
# 17  strava_rest_api_from_config_dataset_2025052702...
#
#                         name
# 0                 _dlt_loads  \
# 1        _dlt_pipeline_state
# 2               _dlt_version
# 3                 activities
# 4     activities__end_latlng
# 5   activities__start_latlng
# 6                 _dlt_loads
# 7        _dlt_pipeline_state
# 8               _dlt_version
# 9                 activities
# 10    activities__end_latlng
# 11  activities__start_latlng
# 12                _dlt_loads
# 13       _dlt_pipeline_state
# 14              _dlt_version
# 15                activities
# 16    activities__end_latlng
# 17  activities__start_latlng
#
#                                          column_names
# 0   [load_id, schema_name, status, inserted_at, sc...  \
# 1   [version, engine_version, pipeline_name, state...
# 2   [version, engine_version, inserted_at, schema_...
# 3   [resource_state, athlete__id, athlete__resourc...
# 4     [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 5     [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 6   [load_id, schema_name, status, inserted_at, sc...
# 7   [version, engine_version, pipeline_name, state...
# 8   [version, engine_version, inserted_at, schema_...
# 9   [resource_state, athlete__id, athlete__resourc...
# 10    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 11    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 12  [load_id, schema_name, status, inserted_at, sc...
# 13  [version, engine_version, pipeline_name, state...
# 14  [version, engine_version, inserted_at, schema_...
# 15  [resource_state, athlete__id, athlete__resourc...
# 16    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
# 17    [value, _dlt_parent_id, _dlt_list_idx, _dlt_id]
#
#                                          column_types  temporary
# 0   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 1   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 2   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 3   [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 4                  [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 5                  [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 6   [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 7   [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 8   [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 9   [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 10                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 11                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 12  [VARCHAR, VARCHAR, BIGINT, TIMESTAMP WITH TIME...      False
# 13  [BIGINT, BIGINT, VARCHAR, VARCHAR, TIMESTAMP W...      False
# 14  [BIGINT, BIGINT, TIMESTAMP WITH TIME ZONE, VAR...      False
# 15  [BIGINT, BIGINT, BIGINT, VARCHAR, DOUBLE, BIGI...      False
# 16                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
# 17                 [DOUBLE, VARCHAR, BIGINT, VARCHAR]      False
